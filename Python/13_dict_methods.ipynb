# %%
student = {
    "name" : "smit",
    "age" : 21,
    "grade" : "A"
}
student["name"]
# Out:
# 'smit'

# %%
student["age"]
# Out:
# 21

# %%
student["grade"]
# Out:
# 'A'

# %%
r = student.get("name4")
r

# %%
print(r)
# Out:
# None

# %%
student = {
    "name" : "smit",
    "age" : 21,
    "grade" : "A"
}
student["name"]

student["age"] = 20
print(student)
# Out:
# {'name': 'smit', 'age': 20, 'grade': 'A'}

# %%
student.keys()
# Out:
# dict_keys(['name', 'age', 'grade'])

# %%
student.values()
# Out:
# dict_values(['smit', 20, 'A'])

# %%
student.items()
# Out:
# dict_items([('name', 'smit'), ('age', 20), ('grade', 'A')])

# %%
student = {
    "name" : "smit",
    "age" : 21,
    "grade" : "A"
}
student.update({"name":"smith","language":"python"})
