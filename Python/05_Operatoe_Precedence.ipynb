# %%
result = 120 + 23 - 29 * 23 / 243
print(result)
# Out:
# 140.2551440329218

# %%
reuslt = 28- 24 * 24 / 32 + 23
print(reuslt)
# Out:
# 33.0

# %%
reuslt = (121 + 23) * 13 / (1321 - 232) * (2342 - 23) / 32
result
# Out:
# 140.2551440329218
