# %%
a = 100
if (a > 50):
    print("Greater the ")
else :
    print("Less then")
# Out:
# Greater the

# %%
#Check the number is zero and positive and negative.
a = int(input("Enter the number you want to check :"))
if (a == 0 ):
    print("Your number is Zero.")
elif (a > 0 ):
    print("Your number is Positive.")
else :
    print("Your number is Negative.")
# Out:
# Enter the number you want to check : 23
# Your number is Positive.
