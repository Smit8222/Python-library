# %%
name = "smit"
print(name)
# Out:
# smit

# %%
print(len(name))
# Out:
# 4

# %%
name.upper()
# Out:
# 'SMIT'

# %%
name.lower()
# Out:
# 'smit'

# %%
name.capitalize()
# Out:
# 'Smit'

# %%
name[1:3]
# Out:
# 'mi'

# %%
name[-2:]
# Out:
# 'it'

# %%
name[-3:3]
# Out:
# 'mi'

# %%
name[1:3]
# Out:
# 'mi'
