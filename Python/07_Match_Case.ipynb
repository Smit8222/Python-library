# %%
code = 200
match code:
    case 200:
        print("Response ok")
    case 400:
        print("Bad Response")
    case _ :
        print("Nothing.")

print("End of the program")
# Out:
# Response ok
# End of the program
