# %%
#ARTHAMECIT OPERATORS
a = 4
b = 4
print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a//b)
print(a%b)
# Out:
# 8
# 0
# 16
# 1.0
# 1
# 0

# %%
#COMPARISON OPERASTOES
a = 5
b = 10
print(a>b)
print(a<b)
print(a>=b)
print(a<=b)
print(a==b)
print(a!=b)
# Out:
# False
# True
# False
# True
# False
# True

# %%
#LOGICAL OPERATORS
A = True
B = False
A and B
A or B
A  B
# Out:
# False
