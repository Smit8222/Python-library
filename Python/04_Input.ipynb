# %%
a  = input("Enter your number as a : ")
# Out:
# Enter your number as a :  10

# %%
b = input("Enter your number as b : ")
# Out:
# Enter your number as b :  10

# %%
int(a) + int(b)
# Out:
# 20
