# %%
empty_tuple = ()
numbers = (1, 2, 3, 4, 5)
mixed_tuple = (1, "Hello", 3.14, True)
single_element = (42,)

# %%
my_tuple = (10, 20, 30, 40)

print(my_tuple[1]) 
print(my_tuple[1:3])
# Out:
# 20
# (20, 30)

# %%
person = ("Alice", 25, "Engineer")
name, age, profession = person
print(name)
print(age)
# Out:
# Alice
# 25
