# %%
import pandas as pd

# %%
s1 = pd.Series([71, 84, 56, 23, 56, 98, 56])

# %%
type(s)
# Out:
# pandas.Series

# %%
print(s)
# Out:
# 0    71
# 1    84
# 2    56
# 3    23
# 4    56
# 5    98
# 6    56
# dtype: int64

# %%
s2 = pd.Series([71, 84, 56, 23, 56, 98, 56], index = ["Smith", "Anushka", "Harry", "Shubh", "Rohan", "Aakash", "Suraj"])

# %%
print(s2)
# Out:
# Smith      71
# Anushka    84
# Harry      56
# Shubh      23
# Rohan      56
# Aakash     98
# Suraj      56
# dtype: int64

# %%
data = {
    "name": ["Alice", "Bob", "Charlie"],
    "age": [25, 30, 35],
    "city": ["Delhi", "Mumbai", "Bangalore"]
}

# %%
df = pd.DataFrame(data)

# %%
print(df)
# Out:
#       name  age       city
# 0    Alice   25      Delhi
# 1      Bob   30     Mumbai
# 2  Charlie   35  Bangalore

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df.columns
# Out:
# Index(['name', 'age', 'city'], dtype='str')
