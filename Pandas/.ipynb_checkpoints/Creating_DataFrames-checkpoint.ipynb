# %%
import pandas as pd

# %%
data =[["smit",99],["Anushka",90],["Tiku",95],["Chakuli",98]]

# %%
print(data)
# Out:
# [['smit', 99], ['Anushka', 90], ['Tiku', 95], ['Chakuli', 98]]

# %%
pd.DataFrame(data, columns = ["Nmae", "Marks"])
# Out:
#       Nmae  Marks
# 0     smit     99
# 1  Anushka     90
# 2     Tiku     95
# 3  Chakuli     98

# %%
import numpy as np

# %%
arr = np.array([[1, 2],[5, 6]])

# %%
df = pd.DataFrame(arr, columns = ["A", "B"])

# %%
print(df)
# Out:
#    A  B
# 0  1  2
# 1  5  6
