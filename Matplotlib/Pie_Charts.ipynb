# %%
import matplotlib.pyplot as plt

# %%
plt.style.use("ggplot")

# %%
labels = ["Sachin", "Sehwag", "Kohli", "Yuvraj"]
runs = [18000, 8000, 12000, 9500]

plt.title("Career Runs of Indian Batsmen")
plt.pie(runs, labels=labels)
# Out:
# ([<matplotlib.patches.Wedge at 0x18489610440>,
#   <matplotlib.patches.Wedge at 0x184fff0cb90>,
#   <matplotlib.patches.Wedge at 0x184fff0ce10>,
#   <matplotlib.patches.Wedge at 0x184fff0d090>],
#  [Text(0.408316888704146, 1.0214094763604684, 'Sachin'),
#   Text(-1.0706592615758088, 0.25236629252327625, 'Sehwag'),
#   Text(-0.5074755072212109, -0.9759449828604966, 'Kohli'),
#   Text(0.8899186414035474, -0.6465638496563697, 'Yuvraj')])

# %%
colors = ['#ff9999','#66b3ff','#99ff99','#ffcc99']
plt.pie(runs, labels=labels, colors=colors)
# Out:
# ([<matplotlib.patches.Wedge at 0x184896c4e10>,
#   <matplotlib.patches.Wedge at 0x184896c5090>,
#   <matplotlib.patches.Wedge at 0x184896c5310>,
#   <matplotlib.patches.Wedge at 0x184896c5590>],
#  [Text(0.408316888704146, 1.0214094763604684, 'Sachin'),
#   Text(-1.0706592615758088, 0.25236629252327625, 'Sehwag'),
#   Text(-0.5074755072212109, -0.9759449828604966, 'Kohli'),
#   Text(0.8899186414035474, -0.6465638496563697, 'Yuvraj')])

# %%
plt.pie(
    runs,
    labels=labels,
    colors=colors,
    wedgeprops={'edgecolor': 'red', 'linewidth': 1, 'linestyle': ':'}
)
plt.show()

# %%
explode = [0.1, 0, 0, 0]
plt.pie(runs, labels=labels, explode=explode, colors=colors)
plt.title("Exploded Pie Example")
plt.show()

# %%
plt.pie(
    runs,
    labels=labels,
    explode=explode,
    colors=colors,
    shadow=True
)
plt.show()

# %%
plt.pie(
    runs,
    labels=labels,
    autopct='%1.1f%%',
    startangle=140
)
plt.title("Career Run Share")

# %%
languages = ['Python', 'Java', 'C++', 'JavaScript', 'C#', 'Ruby', 'Go', 'Rust', 'Swift', 'PHP']
usage = [30, 20, 10, 10, 7, 5, 4, 3, 2, 1]

plt.pie(usage, labels=languages, autopct='%1.1f%%', startangle=90)
plt.title("Programming Language Usage (Crowded Example)")
plt.show()
